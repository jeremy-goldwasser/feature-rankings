# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import pathlib
from os.path import join
path_to_file = str(pathlib.Path().resolve())
dir_path = join(path_to_file, "../../")

# %%
with open(join(dir_path, "Experiments/Results/census_fwers_K_2"), "rb") as fp:
    fwers2 = pickle.load(fp)
with open(join(dir_path, "Experiments/Results/census_fwers_K_5"), "rb") as fp:
    fwers5 = pickle.load(fp)

# %%
fwers = np.array([fwers2, fwers5])
labels = ["K=2", "K=5"]
plt.figure(figsize=(10,3))
plt.boxplot(fwers.T, vert=False, labels=labels, flierprops={'marker': 'o', 'markerfacecolor':'black'})
plt.axvline(20)
plt.xlim([0,25])
plt.title("FWERs of Top-K SHAP rankings")
plt.xlabel("Error Rate (%)")
plt.savefig(join(dir_path, "Experiments", "Figures", "boxplots.png"))
plt.show()
